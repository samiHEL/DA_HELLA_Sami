# %% [markdown]
# <a href="https://colab.research.google.com/github/samiHEL/DA_HELLA_Sami/blob/main/DA_HELLA_Sami.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercice 1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
# import numpy as np
import seaborn 
import matplotlib.pyplot as plot

data = pd.read_csv(r'/content/drive/MyDrive/house_pricing.csv')
print(data.dtypes)

# data=pd.read_csv('house_pricing.csv')
# df = pd.DataFrame(data)

# df.plot(LotArea ='LotArea ', SalePrice='SalePrice', style='o')
# plt.savefig("pandas_scatter_plot_01.png", bbox_inches='tight', dpi=100)
df = pd.DataFrame(data=data, columns=['SalePrice','LotArea'])
seaborn.relplot(x=df["SalePrice"], y=df["LotArea"], s = 100)
plot.show();
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %% [markdown]
# Qestion 3 : Discret car graphique pas continue, nuage de points

# %% [markdown]
# prendre données quantitatives pour faire nuage de point

# %% [markdown]
# Question 4 :

# %%
# df[(df['SalePrice'] < 500000) & (df['LotArea'] < 20000)]
# df.plot.scatter(x='LotArea', y='SalePrice', title= "");
df[(df['SalePrice'] < 500000) & (df['LotArea'] < 20000)].plot.scatter(x = 'SalePrice', y = 'LotArea' , s = 10);
# sortir le dataframe qui sort cette colonne qui correspond à cette condition
# seaborn.regplot(x=df["SalePrice"], y=df["LotArea"], s=100)

plot.show();

# %% [markdown]
# Question 5:

# %%
df = pd.DataFrame(data=data, columns=['LotArea','LotFrontage'])
# df[(df['SalePrice'] < 500000) & (df['LotArea'] < 20000)]
# df.plot.scatter(x='LotArea', y='SalePrice', title= "");
# plot.scatter(x = 'LotFrontage', y = 'LotArea' , s = 100);
seaborn.regplot(x=df["LotFrontage"], y=df["LotArea"])
plot.show();

# %% [markdown]
# Question 6 :

# %%
df[(df['LotFrontage'] < 200) & (df['LotArea'] < 10000)].plot.scatter(x = 'LotFrontage', y = 'LotArea');
plot.show();

# %% [markdown]
# # Exercice 2

# %%
# Out:
#       LotArea  SalePrice
# 0        8450     208500
# 1        9600     181500
# 2       11250     223500
# 3        9550     140000
# 4       14260     250000
# ...       ...        ...
# 1455     7917     175000
# 1456    13175     210000
# 1457     9042     266500
# 1458     9717     142125
# 1459     9937     147500
#
# [1460 rows x 2 columns]

# %%
data = pd.read_csv(r'/content/drive/MyDrive/sales_predictions.csv');data
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day
# 0                 1.0
# 1                 1.0
# 2                -1.0
# 3                 1.0
# 4                 1.0
# ...               ...
# 2935844           1.0
# 2935845           1.0
# 2935846           1.0
# 2935847           1.0
# 2935848           1.0
#
# [2935849 rows x 6 columns]

# %% [markdown]
# Question 2:

# %%
data = pd.read_csv(r'/content/drive/MyDrive/sales_predictions.csv')
print(data.dtypes)
df = pd.DataFrame(data=data, columns=['item_price','date'])
# df


seaborn.relplot(x=df["date"], y=df["item_price"])
plot.show();
# Out:
# date               object
# date_block_num      int64
# shop_id             int64
# item_id             int64
# item_price        float64
# item_cnt_day      float64
# dtype: object

# %% [markdown]
# Question 3 :

# %%
df = pd.DataFrame(data=data, columns=['item_price','date']).sample(n=50)

seaborn.relplot(x=df["date"], y=df["item_price"])
plot.show();

# %% [markdown]
# Question 4:

# %%
seaborn.relplot(x=df["date"], y=df["item_price"], s=120)
plot.show();

# %% [markdown]
# Question 5:

# %%
df = pd.DataFrame(data=data, columns=['date','item_price']).sample(n=50)
value=pd.to_datetime(df["date"], infer_datetime_format=True)
seaborn.relplot(x=value, y=df["item_price"], s=50, height=10)
plot.show(); 
# seaborn.lineplot(x=value, y=df["item_price"])
# plot.show();

# %% [markdown]
# # Exercice 3

# %% [markdown]
# Question 2:

# %%
import pandas as pd
# import numpy as np
import seaborn 
import matplotlib.pyplot as plot
data = pd.read_csv(r'/content/drive/MyDrive/IBM_HR_ATTRITION.csv')
# parametre sep=;
data
df = pd.DataFrame(data=data, columns=['Attrition','JobSatisfaction'])
seaborn.catplot(x="Attrition", y="JobSatisfaction", data=df, height=7)
plot.show();

# %% [markdown]
# Question 3 :

# %%
# bp = df.boxplot(column=['JobSatisfaction', 'YearsAtCompany'])
# bp = df.boxplot(grid=False, rot=45, fontsize=15)
# bp = df.boxplot()

seaborn.boxplot(data=df, x="JobSatisfaction", y="Attrition")

plot.show()

# %% [markdown]
# Question 5 :

# %%
seaborn.boxplot(data=df, x="JobSatisfaction", y="Attrition",showfliers=False)
plot.show()

# %% [markdown]
# Question 6 :

# %%
df.describe()
# faire des stats desssus
# Out:
#        JobSatisfaction
# count      1470.000000
# mean          2.728571
# std           1.102846
# min           1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           4.000000
# max           4.000000

# %% [markdown]
# ecart type trop important, base sur 4 et ecart potentiel de 1,1
# trop important, pas prendre attrition avec jobSatisfaction.

# %% [markdown]
# Question 7 :

# %% [markdown]
# Question 8 :

# %%
df = pd.DataFrame(data=data, columns=['TotalWorkingYears','Attrition'])
seaborn.catplot(x="TotalWorkingYears", y="Attrition", data=df, height=7)
seaborn.boxplot(data=df, x="TotalWorkingYears", y="Attrition")
plot.show()

# %%
seaborn.boxplot(data=df, x="Attrition", y="TotalWorkingYears",showfliers=False)
plot.show()

# %% [markdown]
# Question 9 :

# %%
# df['Attrition'].str.replace("No","0")
df = pd.DataFrame(data=data, columns=['EducationField','Attrition'])
df["Attrition"].replace({"Yes": 1, "No": 0}, inplace=True)
df['Attrition']
seaborn.catplot(x="EducationField", y="Attrition", data= df, kind="bar", height=10)

# %%
df
# Out:
#       Attrition  TotalWorkingYears
# 0             1                  8
# 1             0                 10
# 2             1                  7
# 3             0                  8
# 4             0                  6
# ...         ...                ...
# 1465          0                 17
# 1466          0                  9
# 1467          0                  6
# 1468          0                 17
# 1469          0                  6
#
# [1470 rows x 2 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-ea469526b33d> in <module>
#       1 df = pd.DataFrame(data=data, columns=['EducationField','Attrition'])
# ----> 2 seaborn.catplot(x="EducationField", y="Attrition", data= df, kind="bar", height=10)
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, seed, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3790     p = _CategoricalPlotter()
#    3791     p.require_numeric = plotter_class.require_numeric
# -> 3792     p.establish_variables(x_, y_, hue, data, orient, order, hue_order)
#    3793     if (
#    3794         order is not None
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     155             # Figure out the plotting orientation
#     156             orient = infer_orient(
# --> 157                 x, y, orient, require_numeric=self.require_numeric
#     158             )
#     159
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_core.py in infer_orient(x, y, orient, require_numeric)
#    1350     elif require_numeric and "numeric" not in (x_type, y_type):
#    1351         err = "Neither the `x` nor `y` variable appears to be numeric."
# -> 1352         raise TypeError(err)
#    1353
#    1354     else:
#
# TypeError: Neither the `x` nor `y` variable appears to be numeric.

# %%
data
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# 2                    2          2          Other              1
# 3                    3          4  Life Sciences              1
# 4                    2          1        Medical              1
# ...                ...        ...            ...            ...
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0                  1  ...                         1            80
# 1                  2  ...                         4            80
# 2                  4  ...                         2            80
# 3                  5  ...                         3            80
# 4                  7  ...                         4            80
# ...              ...  ...                       ...           ...
# 1465            2061  ...                         3            80
# 1466            2062  ...                         1            80
# 1467            2064  ...                         2            80
# 1468            2065  ...                         4            80
# 1469            2068  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                  8                      0
# 1                    1                 10                      3
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# ...                ...                ...                    ...
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0                  1               6                  4
# 1                  3              10                  7
# 2                  3               0                  0
# 3                  3               8                  7
# 4                  3               2                  2
# ...              ...             ...                ...
# 1465               3               5                  2
# 1466               3               7                  7
# 1467               3               6                  2
# 1468               2               9                  6
# 1469               4               4                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# ...                       ...                   ...
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [1470 rows x 35 columns]
# Warning: Total number of columns (35) exceeds max_columns (20) limiting to first (20) columns.

# %% [markdown]
# # Exo 4

# %% [markdown]
# Question 2:

# %%
import pandas as pd
# import numpy as np
import seaborn 
import matplotlib.pyplot as plot
data = pd.read_csv(r'/content/drive/MyDrive/house_pricing.csv')

corr=df.iloc[:,-15:].corr()
corr
# Out:
#                WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# WoodDeckSF       1.000000     0.058661      -0.125989  -0.032771    -0.074181
# OpenPorchSF      0.058661     1.000000      -0.093079  -0.005842     0.074304
# EnclosedPorch   -0.125989    -0.093079       1.000000  -0.037305    -0.082864
# 3SsnPorch       -0.032771    -0.005842      -0.037305   1.000000    -0.031436
# ScreenPorch     -0.074181     0.074304      -0.082864  -0.031436     1.000000
# PoolArea         0.073378     0.060762       0.054203  -0.007992     0.051307
# MiscVal         -0.009551    -0.018584       0.018361   0.000354     0.031946
# MoSold           0.021011     0.071255      -0.028887   0.029474     0.023217
# YrSold           0.022270    -0.057619      -0.009916   0.018645     0.010694
# SalePrice        0.324413     0.315856      -0.128578   0.044584     0.111447
#
#                PoolArea   MiscVal    MoSold    YrSold  SalePrice
# WoodDeckSF     0.073378 -0.009551  0.021011  0.022270   0.324413
# OpenPorchSF    0.060762 -0.018584  0.071255 -0.057619   0.315856
# EnclosedPorch  0.054203  0.018361 -0.028887 -0.009916  -0.128578
# 3SsnPorch     -0.007992  0.000354  0.029474  0.018645   0.044584
# ScreenPorch    0.051307  0.031946  0.023217  0.010694   0.111447
# PoolArea       1.000000  0.029669 -0.033737 -0.059689   0.092404
# MiscVal        0.029669  1.000000 -0.006495  0.004906  -0.021190
# MoSold        -0.033737 -0.006495  1.000000 -0.145721   0.046432
# YrSold        -0.059689  0.004906 -0.145721  1.000000  -0.028923
# SalePrice      0.092404 -0.021190  0.046432 -0.028923   1.000000

# %%
data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2008        WD         Normal     208500
# 1         5   2007        WD         Normal     181500
# 2         9   2008        WD         Normal     223500
# 3         2   2006        WD        Abnorml     140000
# 4        12   2008        WD         Normal     250000
# ...     ...    ...       ...            ...        ...
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [1460 rows x 81 columns]

# %%
# Question 3:

f, ax = plot.subplots(figsize=(20,5))
seaborn.heatmap(corr, annot=True, ax =ax)
plot.savefig('heatmapEX1.png')
